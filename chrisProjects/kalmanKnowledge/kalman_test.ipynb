# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# from scipy.stats import norm
from pykalman import KalmanFilter
# %matplotlib inline

# %%
import pandas as pd
data1 = pd.read_csv('Dataset1.csv')

# %%
data1.plot()

# %%
kf = KalmanFilter(transition_matrices = [[1, 1, 1], [0, 1, 0], [0, 0, 1]], 
                  observation_matrices = [[0.1, 0.5, 0.0], [-0.3, 0.0, 0.0]])

# %%
measurements = np.asarray(data1.values)

# %%
kf = kf.em(measurements, n_iter=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cb46c89976ab> in <module>()
# ----> 1 kf = kf.em(measurements, n_iter=5)
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in em(self, X, y, n_iter, em_vars)
#    1407                     self.transition_offsets, self.observation_offsets,
#    1408                     self.initial_state_mean, self.initial_state_covariance,
# -> 1409                     Z
#    1410                 )
#    1411             )
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in _filter(transition_matrices, observation_matrices, transition_covariance, observation_covariance, transition_offsets, observation_offsets, initial_state_mean, initial_state_covariance, observations)
#     391                 predicted_state_means[t],
#     392                 predicted_state_covariances[t],
# --> 393                 observations[t]
#     394             )
#     395         )
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in _filter_correct(observation_matrix, observation_covariance, observation_offset, predicted_state_mean, predicted_state_covariance, observation)
#     276         corrected_state_mean = (
#     277             predicted_state_mean
# --> 278             + np.dot(kalman_gain, observation - predicted_observation_mean)
#     279         )
#     280         corrected_state_covariance = (
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/numpy/ma/core.py in __sub__(self, other)
#    3873         if self._delegate_binop(other):
#    3874             return NotImplemented
# -> 3875         return subtract(self, other)
#    3876
#    3877     def __rsub__(self, other):
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/numpy/ma/core.py in __call__(self, a, b, *args, **kwargs)
#     961         with np.errstate():
#     962             np.seterr(divide='ignore', invalid='ignore')
# --> 963             result = self.f(da, db, *args, **kwargs)
#     964         # Get the mask for the result
#     965         (ma, mb) = (getmask(a), getmask(b))
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %%
(filtered_state_means, filtered_state_covariances) = kf.filter(measurements)
(smoothed_state_means, smoothed_state_covariances) = kf.smooth(measurements)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-29c30773bca1> in <module>()
# ----> 1 (filtered_state_means, filtered_state_covariances) = kf.filter(measurements)
#       2 (smoothed_state_means, smoothed_state_covariances) = kf.smooth(measurements)
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in filter(self, X)
#    1173                 transition_offsets, observation_offsets,
#    1174                 initial_state_mean, initial_state_covariance,
# -> 1175                 Z
#    1176             )
#    1177         )
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in _filter(transition_matrices, observation_matrices, transition_covariance, observation_covariance, transition_offsets, observation_offsets, initial_state_mean, initial_state_covariance, observations)
#     391                 predicted_state_means[t],
#     392                 predicted_state_covariances[t],
# --> 393                 observations[t]
#     394             )
#     395         )
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/pykalman-0.9.5-py3.5.egg/pykalman/standard.py in _filter_correct(observation_matrix, observation_covariance, observation_offset, predicted_state_mean, predicted_state_covariance, observation)
#     276         corrected_state_mean = (
#     277             predicted_state_mean
# --> 278             + np.dot(kalman_gain, observation - predicted_observation_mean)
#     279         )
#     280         corrected_state_covariance = (
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/numpy/ma/core.py in __sub__(self, other)
#    3873         if self._delegate_binop(other):
#    3874             return NotImplemented
# -> 3875         return subtract(self, other)
#    3876
#    3877     def __rsub__(self, other):
#
# /Users/Chris/miniconda3/lib/python3.5/site-packages/numpy/ma/core.py in __call__(self, a, b, *args, **kwargs)
#     961         with np.errstate():
#     962             np.seterr(divide='ignore', invalid='ignore')
# --> 963             result = self.f(da, db, *args, **kwargs)
#     964         # Get the mask for the result
#     965         (ma, mb) = (getmask(a), getmask(b))
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)
